# %%
# Weather Modeling with quadratic equation(Hard-Coded Coefficient)
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time,a,b,c):
  temperature = a * (time ** 2) + b * time + c
  return temperature

def main():
  a=0.1
  b=-1
  c=30
  time_value=np.linspace(0, 10, 50)
  temperature_hardcoded = quadratic_model(time_value,a,b,c)
  plt.plot(time_value, temperature_hardcoded,label=f'Hard-Coded Coefficient: {a,b,c}')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.legend()
  plt.title('Weather Modeling with quadratic equation(Hard-Coded Coefficient)')
  plt.show()

if __name__ == '__main__':
    main()

# %%
# Weather Modeling with user given input and range
import matplotlib.pyplot as plt
import numpy as np

def quadratic_model(time,a,b,c):
  temperature = a * (time ** 2) + b * time + c
  return temperature

def main():
  a=float(input('Enter a value:'))
  b=float(input('Enter b value:'))
  c=float(input('Enter c value:'))
  x=int(input("Enter start time range"))
  y=int(input("Enter final time range"))
  time_value=np.linspace(0, x, y)
  temperature_user = quadratic_model(time_value,a,b,c)
  plt.plot(time_value, temperature_user,label=f'user given values: {a,b,c}')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.legend()
  plt.title('Weather Modeling with user given input and range')
  plt.show()

if __name__ == '__main__':
    main()
# Out:
# Enter a value:1.8
# Enter b value:2
# Enter c value:30
# Enter start time range25
# Enter final time range50

# %%
# Weather Modeling using input given from file
import matplotlib.pyplot as plt
import numpy as np


def quadratic_model(time, a, b, c):

  temperature = a * (time ** 2) + b * time + c
  return temperature

def main():
  with open("coefficients.txt", 'r') as file:
    lines = file.readlines()
    a, b, c = map(float, lines)

  print(f"Read values: a={a}, b={b}, c={c}")

  x=int(input("Enter start time range"))
  y=int(input("Enter final time range"))
  time_value=np.linspace(0, x, y)
  temperature_read = [quadratic_model(t, a, b, c) for t in time_value]

  plt.plot(time_value, temperature_read,label=f'read from file: {a,b,c}')
  plt.xlabel('Time')
  plt.ylabel('Temperature')
  plt.legend()
  plt.title('Weather Modeling using input given from file')
  plt.show()

if __name__ == '__main__':
     main()
# Out:
# Read values: a=2.68, b=0.33, c=-3.45
# Enter start time range25
# Enter final time range100

# %%
# Weather modeling with user given values and range in QE (SINGLE SET INPUT)
import matplotlib.pyplot as plt
import numpy as np

def quad_model(Time, coeffs):
    a, b, c = coeffs
    temp = a * (Time**2) + b * Time + c
    return temp

def main():
    # Input coefficients as a set
    set1 = {float(input("Enter the value of 'a': ")), float(input("Enter the value of 'b': ")), float(input("Enter the value of 'c': "))}
    print(set1)
    print("Give a time range:")
    x = float(input("Enter the start range: "))
    y = float(input("Enter the final range: "))

    time_v = np.linspace(x, y, 50)
    temp_user = quad_model(time_v, set1)

    plt.plot(time_v, temp_user, label=f"Set: {set1}")
    plt.plot(time_v, temp_user, label="single set")
    plt.xlabel("time")
    plt.ylabel("temp")
    plt.legend()
    plt.title("Weather modeling with user given values and range in QE")
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Enter the value of 'a': 2.6
# Enter the value of 'b': 2.33
# Enter the value of 'c': 1
# {1.0, 2.6, 2.33}
# Give a time range:
# Enter the start range: 0
# Enter the final range: 25

# %%
# Weather modeling with user given coefficient sets (MULTIPLE SET INPUTS)
import matplotlib.pyplot as plt
import numpy as np

def quad_model(Time, coeffs):
    a, b, c = coeffs
    temp = a * (Time**2) + b * Time + c
    return temp

def main():
    num_sets = int(input("Enter the number of coefficient sets: "))
    all_sets = []

    for _ in range(num_sets):
        a = float(input("Enter the value of 'a': "))
        b = float(input("Enter the value of 'b': "))
        c = float(input("Enter the value of 'c': "))
        all_sets.append((a, b, c))

    print("Give a time range:")
    x = float(input("Enter the start range: "))
    y = float(input("Enter the final range: "))

    time_v = np.linspace(x, y, 50)

    plt.figure(figsize=(8, 6))
    for coeffs in all_sets:
        temp_user = quad_model(time_v, coeffs)
        plt.plot(time_v, temp_user, label=f"Set: {coeffs}")

    plt.xlabel("Time")
    plt.ylabel("Temperature")
    plt.legend()
    plt.title("Weather modeling with user given coefficient sets")
    plt.grid(True)
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Enter the number of coefficient sets: 3
# Enter the value of 'a': 2.333
# Enter the value of 'b': 5.66
# Enter the value of 'c': 1.1784
# Enter the value of 'a': 1.24883
# Enter the value of 'b': 0.2
# Enter the value of 'c': -0.145
# Enter the value of 'a': 0.1
# Enter the value of 'b': -1
# Enter the value of 'c': 30
# Give a time range:
# Enter the start range: 10
# Enter the final range: 30

# %%
#  Weather Modeling with hard-coded values and user given input
import matplotlib.pyplot as plt
import numpy as np


def quad_model(Time,a,b,c):
        temp = a * (Time**2) + b * Time + c
        return temp
def quad_model2(Time,a,b,c) :
        temp=a*(Time**2)+b*Time+c
        return temp
def main():
        a = 0.1
        b = -1
        c = 30
        a2=float(input("enter the value of a "))
        b2=float(input("entr the value of b "))
        c2=float(input("enetr the value of c "))
        time_v = np.linspace(0, 10, 50)
        temp_hardcoded = quad_model(time_v,a,b,c)
        plt.plot(time_v, temp_hardcoded, label=f"hardcoded values: {a,b,c}")
        temp_user=quad_model2(time_v,a2,b2,c2)
        plt.plot(time_v,temp_user,label=f"user given values: {a2,b2,c2}")
        plt.xlabel("time")
        plt.ylabel('temp')
        plt.legend()
        plt.title("weather modeling with user given values and range in QE")
        plt.show()

2/
if __name__ == "__main__":
        main()
# Out:
# enter the value of a 2.33
# entr the value of b 3.456
# enetr the value of c 4.89
